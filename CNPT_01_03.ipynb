# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/calculonumerico/blob/main/CNPT_01_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Slides:
#
# https://drive.google.com/file/d/1srTuewWllvAmJuiek7ygtkf4pK50JO72/view
#
#
# Vídeo:
#
# https://www.youtube.com/watch?v=k1xG54UZyIQ&list=PLH9knZH6lcgrCjPt7ouHphjuYvuzBfa3U&index=4
