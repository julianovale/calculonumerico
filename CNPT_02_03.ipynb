# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/calculonumerico/blob/main/CNPT_02_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Slides:
#
# https://drive.google.com/file/d/1TCwR2IqPx1EdtVFn82I3DY6jlEK3qR7c/view
#
#
# Vídeo:
#
# https://www.youtube.com/watch?v=4csEIpFNIa0&list=PLH9knZH6lcgrCjPt7ouHphjuYvuzBfa3U&index=22

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.plot(x,y,'r*')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title("Gráfico de X por Y")
plt.grid()
plt.show()
