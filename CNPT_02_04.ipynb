# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/calculonumerico/blob/main/CNPT_02_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Slides:
#
# https://drive.google.com/file/d/1TCwR2IqPx1EdtVFn82I3DY6jlEK3qR7c/view
#
#
# Vídeo:
#
# https://www.youtube.com/watch?v=SUlvOLSiPp8&list=PLH9knZH6lcgrCjPt7ouHphjuYvuzBfa3U&index=23

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(t):
  return np.exp(-t)*np.cos(2*np.pi*t)

# %%
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# %%
plt.figure()
plt.subplot(211) #
plt.grid()
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.grid()
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()
